# %% [markdown]
# # Smart Vehicle Detector (CPU)
#
# The implementation lives in `smart_detector.py`. It uses the CPU-only YOLO path and Google AI Studio's `gemini-3.5-flash-lite` model. Add `GOOGLE_API_KEY` to the project-root `.env` before running.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from smart_detector import CPU_THREADS, FRAME_STRIDE, GEMINI_MODEL, INFERENCE_SIZE

print(f"Device: CPU ({CPU_THREADS} threads)")
print(f"YOLO inference: {INFERENCE_SIZE}px, every {FRAME_STRIDE} displayed frame(s)")
print(f"Gemini model: {GEMINI_MODEL}")

# %%
from smart_detector import SmartVehicleDetector, VIDEO_PATH

processor = SmartVehicleDetector(VIDEO_PATH)
processor.start_processing()
